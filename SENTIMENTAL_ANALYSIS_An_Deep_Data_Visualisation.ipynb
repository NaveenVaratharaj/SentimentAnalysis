# %%
#Importing the required packages

import pandas as pd
import sklearn
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Uploading the Dataset
df =pd.read_csv("Copy of Product review DataFrame.csv")

# %%
#Printing the first ten values in the dataset
df.head(10)
# Out:
#             Product  ... Rating
# 0   OnePlus Nord 5G  ...    5.0
# 1   OnePlus Nord 5G  ...    5.0
# 2   OnePlus Nord 5G  ...    5.0
# 3   OnePlus Nord 5G  ...    5.0
# 4   OnePlus Nord 5G  ...    5.0
# 5   OnePlus Nord 5G  ...    5.0
# 6   OnePlus Nord 5G  ...    5.0
# 7   OnePlus Nord 5G  ...    5.0
# 8   OnePlus Nord 5G  ...    5.0
# 9   OnePlus Nord 5G  ...    5.0
#
# [10 rows x 5 columns]

# %%
#Printing the last ten values in the dataset
df.tail(10)
# Out:
#                Product    Brand  ...                             Review Rating
# 9458   OnePlus Nord 5G  OnePlus  ...                        Bad camera     2.0
# 9459   OnePlus Nord 5G  OnePlus  ...                      Super colour     2.0
# 9460   OnePlus Nord 5G  OnePlus  ...                 Very poor service     2.0
# 9461   OnePlus Nord 5G  OnePlus  ...        This OnePlus not satisfied     2.0
# 9462   OnePlus Nord 5G  OnePlus  ...                              Nord     2.0
# 9463   OnePlus Nord 5G  OnePlus  ...                  Very bad quality     2.0
# 9464   OnePlus Nord 5G  OnePlus  ...                           Descent     2.0
# 9465   OnePlus Nord 5G  OnePlus  ...                             waste     2.0
# 9466   OnePlus Nord 5G  OnePlus  ...                                Oj     2.0
# 9467   OnePlus Nord 5G  OnePlus  ...                            St how     2.0
#
# [10 rows x 5 columns]

# %%
#Dimensions of the dataset
df.shape
# Out:
# (9468, 5)

# %%
#Information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9468 entries, 0 to 9467
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   9468 non-null   object
#  1   Brand     9468 non-null   object
#  2   Username  9468 non-null   object
#  3   Review    9466 non-null   object
#  4   Rating    9195 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 370.0+ KB

# %%
# We need only some of the columns in  the dataframe 
# Removing the unwanted columns

#Needed: 
#NAME, REVIEW , RATING

df.drop("Product", axis = 1, inplace = True)
df.drop("Brand", axis = 1, inplace = True)

# %%
#Printing after removing the columns
df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a.   ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9468 rows x 3 columns]

# %%
#Changing the special characters

spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]
for char in spec_chars:
    df['Username'] = df['Username'].str.replace(char, ' ')

df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9468 rows x 3 columns]

# %%
new_data = df.dropna(axis = 1)
df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9468 rows x 3 columns]

# %%
df.dropna()
df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9468 rows x 3 columns]

# %%
df.isnull().sum()
df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9468 rows x 3 columns]

# %%
df = df.dropna(axis=0, subset=['Review'])
df
# Out:
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9466 rows x 3 columns]

# %%
#Change the type of your Series
df['Review'] = df['Review'].str.replace('$', '')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9466 rows x 3 columns]

# %%
df['Username']= df['Username'].values.astype(str)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# ...

# %%
#Change the type of your Series
df['Username'] = df['Username'].str.replace('$', '')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# [9466 rows x 3 columns]

# %%
df['Username']= df['Username'].values.astype(str)
df

# %%
df['Review'] = df['Review'].str.lower()
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                         Username  ... Rating
# 0                          Amit   ...    5.0
# 1                     aishwarya   ...    5.0
# 2                       vasu a    ...    5.0
# 3               Amazon Customer   ...    5.0
# 4         Manmohan Singh Tanwar   ...    5.0
# ...                          ...  ...    ...
# 9463               DHIRAJ KUMAR   ...    2.0
# 9464                 Farhan Ali   ...    2.0
# 9465                    Aftab N   ...    2.0
# 9466           sukhmander singh   ...    2.0
# 9467               Ramu chukka    ...    2.0
#
# ...

# %%
#Allocating the user review with a name
df['Analysis'] = df['Rating'].map({1 : "Very Worst",
                                 2 : "Bad",
                                 3 : "Decent",
                                 4 : "Good",
                                 5 : "Excellent"})

df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                         Username  ...   Analysis
# 0                          Amit   ...  Excellent
# 1                     aishwarya   ...  Excellent
# 2                       vasu a    ...  Excellent
# 3               Amazon Customer   ...  Excellent
# 4         Manmohan Singh Tanwar   ...  Excellent
# ...                          ...  ...        ...
# 9463               DHIRAJ KUMAR   ...        Bad
# 9464                 Farhan Ali   ...        Bad
# 9465                    Aftab N   ...        Bad
# 9466           sukhmander singh   ...        Bad
# 9467               Ramu chukka    ...        Bad
#
# [9466 rows x 4 columns]

# %%
#Checking the duplicated
df.duplicated('Username')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9463    False
# 9464    False
# 9465    False
# 9466    False
# 9467    False
# Length: 9466, dtype: bool

# %%
#Data visualisation

df['Rating'].value_counts().plot(kind = "bar")
plt.title('Customer Review')
plt.xlabel('Review sentiment')
plt.ylabel("Review Count")
plt.show()

df['Rating'].value_counts().plot(kind = "pie")
plt.title('Customer Review')
plt.xlabel('Review sentiment')
plt.ylabel("Review Count")
plt.show()

df['Rating'].value_counts().plot(kind = "hist")
plt.title('Customer Review')
plt.xlabel('Review sentiment')
plt.ylabel("Review Count")
plt.show()
